# %% [markdown]
# # Independent Learning of "Pandas"

# %% [markdown]
# This is learning from [YouTube](https://www.youtube.com/watch?v=vmEHCJofslg&t=247s)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("pokemon_data.csv")

# %%
print(df.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
df_xlsx = pd.read_excel("pokemon_data.xlsx")

# %%
(df_xlsx.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df_text = pd.read_csv("pokemon_data.txt")

print(df_text)
# Out:
#     #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0    1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1    2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2    3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3    3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4    4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...
# ..                                                 ...
# 795  719\tDiancie\tRock\tFairy\t50\t100\t150\t100\t...
# 796  719\tDiancieMega Diancie\tRock\tFairy\t50\t160...
# 797  720\tHoopaHoopa Confined\tPsychic\tGhost\t80\t...
# 798  720\tHoopaHoopa Unbound\tPsychic\tDark\t80\t16...
# 799  721\tVolcanion\tFire\tWater\t80\t110\t120\t130...
#
# [800 rows x 1 columns]

# %%
df_text = pd.read_csv("pokemon_data.txt", delimiter = '\t')

# %%
print(df_text)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df["Name"][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df.Name)
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df[["Name", "Type 1", "HP"]])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
print(df.head(4))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.iloc[1:4])

#getting specific lows
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
for index, row in df.iterrows(): 
    print(index, row["Name"])
    
# THIS IS A LOOP
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df["Type 1"] == "Fire"]

 #dataframe.location   #[column = "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.iloc[1:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.loc[df["Type 1"] == "Grass"]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values("Name", ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1", "HP"], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] + df["Speed"]

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#Dropping a column

df = df.drop(columns=["Total"])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Total"] = df.iloc[:,4:10].sum(axis=1)

# all rows [row, column]

# %%
df[["Total", "HP", "Defense"]]
# Out:
#      Total  HP  Defense
# 0      318  45       49
# 1      405  60       63
# 2      525  80       83
# 3      625  80      123
# 4      309  39       43
# ..     ...  ..      ...
# 795    600  50      150
# 796    700  50      110
# 797    600  80       60
# 798    680  80       60
# 799    600  80      120
#
# [800 rows x 3 columns]

# %%
cols = list(df.columns)

print(cols)

df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

df.head(5)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']
#    #                   Name Type 1  Type 2  Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    318  45      49
# 1  2                Ivysaur  Grass  Poison      False    405  60      62
# 2  3               Venusaur  Grass  Poison      False    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80     100
# 4  4             Charmander   Fire     NaN      False    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
df.to_csv("modified2.csv", index=False)

# %%
df.to_excel("modified.xlsx", index=False)

# %%
df.to_csv("modified3.txt", index=False, sep='\t')

# %% [markdown]
# # Filtering Data!!

# %%
df.loc[df["Type 1"] == "Grass"]
# Out:
#        #                   Name Type 1    Type 2  Legendary  Total   HP  \
# 0      1              Bulbasaur  Grass    Poison      False    318   45
# 1      2                Ivysaur  Grass    Poison      False    405   60
# 2      3               Venusaur  Grass    Poison      False    525   80
# 3      3  VenusaurMega Venusaur  Grass    Poison      False    625   80
# 48    43                 Oddish  Grass    Poison      False    320   45
# ..   ...                    ...    ...       ...        ...    ...  ...
# 718  650                Chespin  Grass       NaN      False    313   56
# 719  651              Quilladin  Grass       NaN      False    405   61
# 720  652             Chesnaught  Grass  Fighting      False    530   88
# 740  672                 Skiddo  Grass       NaN      False    350   66
# 741  673                 Gogoat  Grass       NaN      False    531  123
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.loc[(df["Type 1"] == "Grass") & (df['Type 2'] == "Poison")]

# &
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    318   45      49
# 1      2                Ivysaur  Grass  Poison      False    405   60      62
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 48    43                 Oddish  Grass  Poison      False    320   45      50
# 49    44                  Gloom  Grass  Poison      False    395   60      65
# 50    45              Vileplume  Grass  Poison      False    490   75      80
# 75    69             Bellsprout  Grass  Poison      False    300   50      75
# 76    70             Weepinbell  Grass  Poison      False    390   65      90
# 77    71             Victreebel  Grass  Poison      False    490   80     105
# 344  315                Roselia  Grass  Poison      False    400   50      60
# ...

# %%
df.loc[(df["Type 1"] == "Grass") | (df['Type 2'] == "Poison")]

# | means "OR"
# Out:
#        #                   Name Type 1    Type 2  Legendary  Total   HP  \
# 0      1              Bulbasaur  Grass    Poison      False    318   45
# 1      2                Ivysaur  Grass    Poison      False    405   60
# 2      3               Venusaur  Grass    Poison      False    525   80
# 3      3  VenusaurMega Venusaur  Grass    Poison      False    625   80
# 16    13                 Weedle    Bug    Poison      False    195   40
# ..   ...                    ...    ...       ...        ...    ...  ...
# 718  650                Chespin  Grass       NaN      False    313   56
# 719  651              Quilladin  Grass       NaN      False    405   61
# 720  652             Chesnaught  Grass  Fighting      False    530   88
# 740  672                 Skiddo  Grass       NaN      False    350   66
# 741  673                 Gogoat  Grass       NaN      False    531  123
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
new_df = df.loc[(df["Type 1"] == "Grass") & (df['Type 2'] == "Poison") & (df["HP"] > 70)]

# %%
new_df = new_df.reset_index(drop=True)

new_df
# Out:
#      #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0    3               Venusaur  Grass  Poison      False    525   80      82
# 1    3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 2   45              Vileplume  Grass  Poison      False    490   75      80
# 3   71             Victreebel  Grass  Poison      False    490   80     105
# 4  591              Amoonguss  Grass  Poison      False    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       83      100      100     80           1
# 1      123      122      120     80           1
# 2       85      110       90     50           1
# 3       65      100       70     70           1
# 4       70       85       80     30           5

# %%
df.loc[df["Name"].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Legendary  Total  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      False    625
# 7      6  CharizardMega Charizard X      Fire    Dragon      False    634
# 8      6  CharizardMega Charizard Y      Fire    Flying      False    634
# 12     9    BlastoiseMega Blastoise     Water       NaN      False    630
# 19    15      BeedrillMega Beedrill       Bug    Poison      False    495
# 23    18        PidgeotMega Pidgeot    Normal    Flying      False    579
# 71    65      AlakazamMega Alakazam   Psychic       NaN      False    590
# 87    80        SlowbroMega Slowbro     Water   Psychic      False    590
# 102   94          GengarMega Gengar     Ghost    Poison      False    600
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      False    590
# 137  127          PinsirMega Pinsir       Bug    Flying      False    600
# 141  130      GyaradosMega Gyarados     Water      Dark      False    640
# ...

# %%
df.loc[~df["Name"].str.contains("Mega")]
# Out:
#        #                 Name   Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison      False    318   45      49
# 1      2              Ivysaur    Grass  Poison      False    405   60      62
# 2      3             Venusaur    Grass  Poison      False    525   80      82
# 4      4           Charmander     Fire     NaN      False    309   39      52
# 5      5           Charmeleon     Fire     NaN      False    405   58      64
# ..   ...                  ...      ...     ...        ...    ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground       True    600  108     100
# 795  719              Diancie     Rock   Fairy       True    600   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost       True    600   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark       True    680   80     160
# 799  721            Volcanion     Fire   Water       True    600   80     110
#
# ...

# %%
import re

df.loc[df["Type 1"].str.contains("Fire|Grass", regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    318   45      49
# 1      2                Ivysaur  Grass  Poison      False    405   60      62
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 4      4             Charmander   Fire     NaN      False    309   39      52
# ..   ...                    ...    ...     ...        ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False    369   62      50
# 736  668                 Pyroar   Fire  Normal      False    507   86      68
# 740  672                 Skiddo  Grass     NaN      False    350   66      65
# 741  673                 Gogoat  Grass     NaN      False    531  123     100
# 799  721              Volcanion   Fire   Water       True    600   80     110
#
# ...

# %%
df.loc[df["Type 1"].str.contains("fire|grass", flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary  Total   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False    318   45      49
# 1      2                Ivysaur  Grass  Poison      False    405   60      62
# 2      3               Venusaur  Grass  Poison      False    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False    625   80     100
# 4      4             Charmander   Fire     NaN      False    309   39      52
# ..   ...                    ...    ...     ...        ...    ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False    369   62      50
# 736  668                 Pyroar   Fire  Normal      False    507   86      68
# 740  672                 Skiddo  Grass     NaN      False    350   66      65
# 741  673                 Gogoat  Grass     NaN      False    531  123     100
# 799  721              Volcanion   Fire   Water       True    600   80     110
#
# ...

# %%
df.loc[df["Name"].str.contains("^pi[a=z]*", flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    251   40
# 21    17            Pidgeotto    Normal    Flying      False    349   63
# 22    18              Pidgeot    Normal    Flying      False    479   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False    579   83
# 30    25              Pikachu  Electric       NaN      False    320   35
# 136  127               Pinsir       Bug       NaN      False    500   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False    600   65
# 186  172                Pichu  Electric       NaN      False    205   20
# 219  204               Pineco       Bug       NaN      False    290   50
# 239  221            Piloswine       Ice    Ground      False    450  100
# 438  393               Piplup     Water       NaN      False    314   53
# 558  499              Pignite      Fire  Fighting      False    418   90
# ...

# %% [markdown]
# # Conditional Changes

# %%
df["Type 1"] 

df.loc[df["Type 1"] == "Fire", "Type 1"] = "Flamer" 

df

df.loc[df["Type 1"] == "Flamer", "Type 1"] = "Fire"

# %%
df.loc[df["Type 1"] == "Flamer", "Type 1"] = "Fire"

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total  HP  \
# 0      1              Bulbasaur    Grass  Poison      False    318  45
# 1      2                Ivysaur    Grass  Poison      False    405  60
# 2      3               Venusaur    Grass  Poison      False    525  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625  80
# 4      4             Charmander     Fire     NaN      False    309  39
# ..   ...                    ...      ...     ...        ...    ...  ..
# 795  719                Diancie     Rock   Fairy       True    600  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680  80
# 799  721              Volcanion     Fire   Water       True    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %% [markdown]
# # Aggregate Statistics (GroupBy)

# %%
df = pd.read_csv("modified.csv")

df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Legendary  \
# 0             0    1              Bulbasaur    Grass  Poison      False
# 1             1    2                Ivysaur    Grass  Poison      False
# 2             2    3               Venusaur    Grass  Poison      False
# 3             3    3  VenusaurMega Venusaur    Grass  Poison      False
# 4             4    4             Charmander     Fire     NaN      False
# ..          ...  ...                    ...      ...     ...        ...
# 795         795  719                Diancie     Rock   Fairy       True
# 796         796  719    DiancieMega Diancie     Rock   Fairy       True
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost       True
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark       True
# 799         799  721              Volcanion     Fire   Water       True
#
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Defense", ascending=False)
# Out:
#           Unnamed: 0           #  Legendary       Total         HP  \
# Type 1
# Steel     486.296296  442.851852   0.148148  487.703704  65.222222
# Rock      431.840909  392.727273   0.090909  453.750000  65.363636
# Dragon    521.843750  474.375000   0.375000  550.531250  83.312500
# Ground    392.312500  356.281250   0.125000  437.500000  73.781250
# Ghost     536.281250  486.500000   0.062500  439.562500  64.437500
# Water     333.312500  303.089286   0.035714  430.455357  72.062500
# Ice       465.666667  423.541667   0.083333  433.458333  72.000000
# Grass     380.414286  344.871429   0.042857  421.142857  67.271429
# Bug       368.072464  334.492754   0.000000  378.927536  56.884058
# Dark      507.387097  461.354839   0.064516  445.741935  66.806452
# Poison    278.285714  251.785714   0.000000  399.142857  67.250000
# Fire      360.942308  327.403846   0.096154  458.076923  69.903846
# Psychic   420.105263  380.807018   0.245614  475.947368  70.631579
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("Attack", ascending=False)
# Out:
#           Unnamed: 0           #  Legendary       Total         HP  \
# Type 1
# Dragon    521.843750  474.375000   0.375000  550.531250  83.312500
# Fighting  400.444444  363.851852   0.000000  416.444444  69.851852
# Ground    392.312500  356.281250   0.125000  437.500000  73.781250
# Rock      431.840909  392.727273   0.090909  453.750000  65.363636
# Steel     486.296296  442.851852   0.148148  487.703704  65.222222
# Dark      507.387097  461.354839   0.064516  445.741935  66.806452
# Fire      360.942308  327.403846   0.096154  458.076923  69.903846
# Flying    746.500000  677.750000   0.500000  485.000000  70.750000
# Poison    278.285714  251.785714   0.000000  399.142857  67.250000
# Water     333.312500  303.089286   0.035714  430.455357  72.062500
# Ghost     536.281250  486.500000   0.062500  439.562500  64.437500
# Normal    351.581633  319.173469   0.020408  401.683673  77.275510
# Grass     380.414286  344.871429   0.042857  421.142857  67.271429
# ...

# %%
df.groupby(["Type 1"]).mean().sort_values("HP", ascending=False)
# Out:
#           Unnamed: 0           #  Legendary       Total         HP  \
# Type 1
# Dragon    521.843750  474.375000   0.375000  550.531250  83.312500
# Normal    351.581633  319.173469   0.020408  401.683673  77.275510
# Fairy     494.529412  449.529412   0.058824  413.176471  74.117647
# Ground    392.312500  356.281250   0.125000  437.500000  73.781250
# Water     333.312500  303.089286   0.035714  430.455357  72.062500
# Ice       465.666667  423.541667   0.083333  433.458333  72.000000
# Flying    746.500000  677.750000   0.500000  485.000000  70.750000
# Psychic   420.105263  380.807018   0.245614  475.947368  70.631579
# Fire      360.942308  327.403846   0.096154  458.076923  69.903846
# Fighting  400.444444  363.851852   0.000000  416.444444  69.851852
# Grass     380.414286  344.871429   0.042857  421.142857  67.271429
# Poison    278.285714  251.785714   0.000000  399.142857  67.250000
# Dark      507.387097  461.354839   0.064516  445.741935  66.806452
# ...

# %%
df.groupby(["Type 1"]).count()

df["count"] = 1

df.groupby(["Type 1"]).count()["count"]
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(["Type 1", "Type 2"]).count()["count"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
for df in pd.read_csv("modified.csv", chunksize = 5):
    print("chunk df")
    print(df)
# Out:
# chunk df
#    Unnamed: 0  #                   Name Type 1  Type 2  Legendary  Total  HP  \
# 0           0  1              Bulbasaur  Grass  Poison      False    318  45
# 1           1  2                Ivysaur  Grass  Poison      False    405  60
# 2           2  3               Venusaur  Grass  Poison      False    525  80
# 3           3  3  VenusaurMega Venusaur  Grass  Poison      False    625  80
# 4           4  4             Charmander   Fire     NaN      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      49       49       65       65     45           1
# 1      62       63       80       80     60           1
# 2      82       83      100      100     80           1
# 3     100      123      122      120     80           1
# 4      52       43       60       50     65           1
# chunk df
#    Unnamed: 0  #                       Name Type 1  Type 2  Legendary  Total  \
# ...
